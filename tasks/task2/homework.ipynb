# %% [markdown]
# # **Домашняя работа**

# %% [markdown]
# ## **№1**![image.png](attachment:image.png)

# %% [markdown]
# ## **№2**
# ![image.png](attachment:image.png)

# %% [markdown]
# ## **№3**
# ![image.png](attachment:image.png)
